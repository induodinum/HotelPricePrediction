# %%
import pickle
import pandas as pd

from datetime import datetime

# %%
datapath = '../data/'

data_static = pickle.load(open(datapath + 'data_static_21_13.pickle','rb'))
data_vary = pickle.load(open(datapath + 'data_vary_21_13.pickle','rb'))
data_price = pickle.load(open(datapath + 'hotel_price_2019-04-10_1.pkl','rb'))

# %%
df = pd.DataFrame(data_static)

# %%
df
# Out:
#       hotel_id_in_our_database                                 hotel_name  \
# 0                            0                    The Bedroom Ladprao 101
# 1                            1                           Nasa Vegas Hotel
# 2                            2                       Romance Hotel Bangna
# 3                            3                           MonkeyNap Hostel
# 4                            4                              SC Park Hotel
# 5                            5              B2 Bangkok Hotel - Srinakarin
# 6                            6                        The Embassy Sathorn
# 7                            8                           Siam Privi Hotel
# 8                            9                             De Botan Hotel
# 9                           10                     The Boss Sathorn Hotel
# 10                          12                Ten Ekamai Suites by Aspira
# 11                          13                      48Metro Hotel Bangkok
# ...

# %%
df2 = pd.DataFrame(data_vary)

# %%
df2
# Out:
#        hotel_id_in_our_database  hotel_user_Ratings hotel_user_Ratings_text  \
# 0                             0                 8.1               Excellent
# 1                             0                 8.1               Excellent
# 2                             0                 8.1               Excellent
# 3                             0                 8.1               Excellent
# 4                             0                 8.1               Excellent
# 5                             0                 8.1               Excellent
# 6                             0                 8.1               Excellent
# 7                             0                 8.1               Excellent
# 8                             0                 8.1               Excellent
# 9                             0                 8.1               Excellent
# 10                            0                 8.1               Excellent
# ...

# %%
df3 = pd.DataFrame(data_price)
df3
# Out:
#                              Hotel_name  \
# 0   Kinnon Deluxe Hostel Coworking Cafe
# 1   Kinnon Deluxe Hostel Coworking Cafe
# 2   Kinnon Deluxe Hostel Coworking Cafe
# 3   Kinnon Deluxe Hostel Coworking Cafe
# 4   Kinnon Deluxe Hostel Coworking Cafe
# 5   Kinnon Deluxe Hostel Coworking Cafe
# 6   Kinnon Deluxe Hostel Coworking Cafe
# 7   Kinnon Deluxe Hostel Coworking Cafe
# 8   Kinnon Deluxe Hostel Coworking Cafe
# 9   Kinnon Deluxe Hostel Coworking Cafe
# 10  Kinnon Deluxe Hostel Coworking Cafe
# 11  Kinnon Deluxe Hostel Coworking Cafe
# 12  Kinnon Deluxe Hostel Coworking Cafe
# 13  Kinnon Deluxe Hostel Coworking Cafe
# 14                 Cubic Bangkok Hostel
# 15                 Cubic Bangkok Hostel
# 16                 Cubic Bangkok Hostel
# 17                 Cubic Bangkok Hostel
# 18                 Cubic Bangkok Hostel
# 19                 Cubic Bangkok Hostel
# 20                 Cubic Bangkok Hostel
# 21                 Cubic Bangkok Hostel
# ...

# %%
hname = set(data_price['Hotel_name'])
hprice = list(data_price['Hotel_prices'])
hbenefits = list(data_price['Hotel_benefits'])
time_collected = list(data_price['Time_collect'])

print(len(hbenefits))
print(len(time_collected))
# pd.DataFrame.from_dict({'hname':hname, 'hprice':hprice, 'hbenefits':hbenefits})
list(hname)
# Out:
# 2596
# 2480
# ['Pakdee Pratunam Bed and Breakfast',
#  'Sabaidee Minitel Hotel',
#  'New Siam Palace Ville',
#  'The Key Sukhumvit Bangkok by Compass Hospitality',
#  'Holiday Inn Express Bangkok Sukhumvit 11',
#  'BelAire Bangkok Sukhumvit',
#  'Asoke Montri Hostel',
#  "Grandpa's Hostel Bangkok",
#  'Sourire at Rattanakosin Island Hotel',
#  'NRC Residence Suvarnabhumi',
#  'D Varee Diva Bally Sukhumvit Hotel',
#  'Phachara Suites Sukhumvit',
#  'Maderla',
#  'Casa Residence Hotel Bangkok',
#  'Meet Inn @Silom',
#  'Smore Hotel Sala Daeng',
#  'Grand Asoke Residence Sukhumvit',
#  'Mango Bedroom Inn',
#  'Aim House Bangkok',
#  'Park Village Serviced Suites',
#  'Jasmine 59 Hotel',
#  'Warm White Hostel',
#  'Vince Hotel Pratunam',
#  'Stay Hostel',
#  'S33 Compact Sukhumvit Hotel',
#  'B2 Bangna Premier Hotel',
#  'iCheck inn Residence Sathorn',
#  'Citadines Sukhumvit 11 Bangkok',
#  'Tai-Pan Hotel',
#  'Mybed Ratchada Hotel',
#  'Petit Hostel Bangkok',
# ...
