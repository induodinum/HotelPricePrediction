# %%
import pickle
import pandas as pd

from datetime import datetime

# %%
data_static = pickle.load(open(datapath + 'data_static_21_13.pickle','rb'))
data_vary = pickle.load(open('data_vary_21_13.pickle','rb'))
data_price = pickle.load(open('hotel_price_2019-04-07.pkl','rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a5b14a789b82> in <module>()
# ----> 1 data_static = pickle.load(open('data_static_21_13.pickle','rb'))
#       2 data_vary = pickle.load(open('data_vary_21_13.pickle','rb'))
#       3 data_price = pickle.load(open('hotel_price_2019-04-07.pkl','rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_static_21_13.pickle'

# %%
df = pd.DataFrame(data_static)

# %%
df
# Out:
#       hotel_id_in_our_database                                 hotel_name  \
# 0                            0                    The Bedroom Ladprao 101
# 1                            1                           Nasa Vegas Hotel
# 2                            2                       Romance Hotel Bangna
# 3                            3                           MonkeyNap Hostel
# 4                            4                              SC Park Hotel
# 5                            5              B2 Bangkok Hotel - Srinakarin
# 6                            6                        The Embassy Sathorn
# 7                            8                           Siam Privi Hotel
# 8                            9                             De Botan Hotel
# 9                           10                     The Boss Sathorn Hotel
# 10                          12                Ten Ekamai Suites by Aspira
# 11                          13                      48Metro Hotel Bangkok
# ...

# %%
df2 = pd.DataFrame(data_vary)

# %%
df2
# Out:
#        hotel_id_in_our_database  hotel_user_Ratings hotel_user_Ratings_text  \
# 0                             0                 8.1               Excellent
# 1                             0                 8.1               Excellent
# 2                             0                 8.1               Excellent
# 3                             0                 8.1               Excellent
# 4                             0                 8.1               Excellent
# 5                             0                 8.1               Excellent
# 6                             0                 8.1               Excellent
# 7                             0                 8.1               Excellent
# 8                             0                 8.1               Excellent
# 9                             0                 8.1               Excellent
# 10                            0                 8.1               Excellent
# ...

# %%
df3 = pd.DataFrame(data_price)
df3
