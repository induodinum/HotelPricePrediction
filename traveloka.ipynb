# %%
from selenium import webdriver 
from bs4 import BeautifulSoup
import time
from datetime import date, datetime, timedelta
import urllib.request
import urllib.parse
from bs4 import BeautifulSoup
from time import sleep
import copy
import numpy as np
import pandas as pd

# %%
url1 = 'https://www.traveloka.com/th-th/hotel/search?spec='
url2 = '.1.1.HOTEL_GEO.10000045.Bangkok%2C%20Thailand.2'
# https://www.traveloka.com/th-th/hotel/search?spec=10-2-2019.11-2-2019.1.1.HOTEL_GEO.10000045.Bangkok%2C%20Thailand.2
current_date = datetime.now().date()
com = '/Users/pudit/Downloads/chromedriver'
sleep =  time.sleep(2)
def all_hotel(n):
    for i in range(n) : 
        s_results = []
        sleep =  time.sleep(2)
        current_date = datetime.now().date() + timedelta(days = i)
        next_date = current_date + timedelta(days = 1)
        url = url1 + current_date.strftime('%d-%-m-%Y') + '.' + next_date.strftime('%d-%-m-%Y') + url2 
        driver = webdriver.Chrome(com)
        driver.get(url)
        sleep
        sleep
        hotel_class_xpath = '//div[@class="_1h2bd"]'
        sleep
        driver.implicitly_wait(5)
        all_click_elements = driver.find_elements_by_xpath(hotel_class_xpath)
#         driver.find_element_by_xpath(hotel_class_xpath).click()
#         driver.implicitly_wait(3)
#         search_result_url = driver.current_url
#         s_results.append(search_result_url)
#         driver.close()
    result = pd.DataFrame()
    return all_click_elements ,driver,result

# %%
def collect_data(all_click_elements,driver,result) :

    for i in range(len(all_click_elements)) :
        all_click_elements[i].click() 
        sleep 
        driver.switch_to_window(driver.window_handles[1]) 
        df_tmp = data_each_hotel()
        result = result.append(df_tmp)
        driver.close()
        driver.switch_to_window(driver.window_handles[0]) 
    return result

# %%
result = pd.DataFrame()
for i in range(len(all_click_elements[0:3])) :
    all_click_elements[i].click() 
    sleep 
    driver.switch_to_window(driver.window_handles[1]) 
    df_tmp = data_each_hotel()
    result = result.append(df_tmp)
    driver.close()
    driver.switch_to_window(driver.window_handles[0])
# Out:
# /Users/pudit/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: use driver.switch_to.window instead
#   """
# /Users/pudit/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: use driver.switch_to.window instead
#   if __name__ == '__main__':

# %%
len(all_click_elements)
# Out:
# 95

# %%
all_click_elements,driver = all_hotel(1)
# result = collect_data(all_click_elements,driver)

# %%
# all_click_elements[1].click() 
# sleep 
# driver.switch_to_window(driver.window_handles[1]) 
r = data_each_hotel()

# %%
hotel_class_xpath = '//div[@class="_1h2bd"]'
all_click_elements = driver.find_elements_by_xpath(hotel_class_xpath)

# %%
# x = soup.find(class_='_3HD0_ tvat-roomName' )
# x
def click_etc() :
    room_xpath = '//div[@class="_1SviU tvat-toggleAllRooms"]'
    room_elements = driver.find_elements_by_xpath(room_xpath) 
    for i in range(len(room_elements)) :
        room_elements[i].click()
        time.sleep(3)
    time.sleep(3)
    each_hotel_raw_html = driver.execute_script("return document.documentElement.outerHTML")
    soup = BeautifulSoup(each_hotel_raw_html,'lxml')
    return soup
# soup.findAll(class_='_3HD0_ tvat-roomName' )

# %%
def check_none(name,List) :
    if name is not None :
        List.append(name.get_text())
    else :
        List.append('None')
    return List

# %%
def data_each_hotel() :
    click_etc()
    driver.implicitly_wait(3)
    time.sleep(2)
    each_hotel_raw_html = driver.execute_script("return document.documentElement.outerHTML")
    soup = BeautifulSoup(each_hotel_raw_html,'lxml')
    time.sleep(5)
    roomName = [] ; bedType = [] ; refund = [] ; breakfast = [] ; Wifi = [] ; realPrice = [] ; disPrice = [] ; 
    save =[] ; Tax = [] ; hotelName = [];
    
    for i in soup.findAll(class_='yob74' ) :
        hotel_name = soup.find(class_="_3nicH tvat-hotelName")
        hotelName.append(hotel_name.get_text())
        room_name = i.find(class_='_3HD0_ tvat-roomName')
        roomName.append(room_name.get_text())
        bed_type = i.find(class_="_24P5a tvat-roomBedType")
        check_none(bed_type,bedType)
        refun = i.find(class_="_216CV")
        check_none(refun,refund)
        rice = refun.find_next(class_="_216CV")
        check_none(rice,breakfast)
        wifi = rice.find_next(class_="_216CV")
        check_none(wifi,Wifi)
        rp = i.find(class_="Y5Dqs")
        check_none(rp,realPrice) 
        dp = i.find(class_='_2qcja tvat-roomPrice')
        check_none(dp,disPrice)
        s = i.find(class_="_2ZXo8")
        check_none(s,save)
        tax = i.find(class_="_1pqB-")
        check_none(tax,Tax)
        df = pd.DataFrame(np.array([hotelName,roomName,bedType,refund,breakfast,Wifi,realPrice,disPrice,save,Tax]),\
                 index=['hotelName','roomName','bedType','refund','breakfast','Wifi','realPrice','disPrice','Save','Tax']).T
    return df

# %%
all_click_elements,driver,result = all_hotel(1)
result = collect_data(all_click_elements[0:2],driver,result)
driver.close()
# Out:
# /Users/pudit/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: use driver.switch_to.window instead
#
# /Users/pudit/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: use driver.switch_to.window instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
driver.close()

# %%
result
# Out:
#            hotelName                                       roomName  \
# 0   โรงแรมนาซ่าเวกัส                        Deluxe Double Room Only
# 1   โรงแรมนาซ่าเวกัส           Deluxe Premium Double/twin Room Only
# 2   โรงแรมนาซ่าเวกัส                   Deluxe Double With Breakfast
# 3   โรงแรมนาซ่าเวกัส                  Super Deluxe Double Room Only
# 4   โรงแรมนาซ่าเวกัส                          Deluxe Twin Room Only
# 5   โรงแรมนาซ่าเวกัส         Executive Deluxe Double/twin Room Only
# 6   โรงแรมนาซ่าเวกัส       Super Deluxe Premium Twin With Breakfast
# 7   โรงแรมนาซ่าเวกัส                     Deluxe Twin With Breakfast
# 8   โรงแรมนาซ่าเวกัส                    Super Deluxe Twin Room Only
# 9   โรงแรมนาซ่าเวกัส  Executive Super Deluxe Double/twin Room  Only
# 0   ซันนี เรสซิเดนซ์                             Superior Room Only
# 1   ซันนี เรสซิเดนซ์                   Superior Room With Breakfast
# 2   ซันนี เรสซิเดนซ์                   Superior Room With Breakfast
# 3   ซันนี เรสซิเดนซ์            Superior Room With One Way Transfer
# 4   ซันนี เรสซิเดนซ์            Superior Room With One Way Transfer
# 5   ซันนี เรสซิเดนซ์                               Deluxe Room Only
# 6   ซันนี เรสซิเดนซ์                               Deluxe Room Only
# 7   ซันนี เรสซิเดนซ์         Superior Room With Round Trip Transfer
# 8   ซันนี เรสซิเดนซ์         Superior Room With Round Trip Transfer
# 9   ซันนี เรสซิเดนซ์      Superior Room With Breakfast And Transfer
# 10  ซันนี เรสซิเดนซ์      Superior Room With Breakfast And Transfer
# 11  ซันนี เรสซิเดนซ์                     Deluxe Room With Breakfast
# 12  ซันนี เรสซิเดนซ์                     Deluxe Room With Breakfast
# 13  ซันนี เรสซิเดนซ์              Deluxe Room With One Way Transfer
# 14  ซันนี เรสซิเดนซ์              Deluxe Room With One Way Transfer
# 15  ซันนี เรสซิเดนซ์           Deluxe Room With Round Trip Transfer
# 16  ซันนี เรสซิเดนซ์           Deluxe Room With Round Trip Transfer
# 17  ซันนี เรสซิเดนซ์        Deluxe Room With Breakfast And Transfer
# 18  ซันนี เรสซิเดนซ์        Deluxe Room With Breakfast And Transfer
# 19  ซันนี เรสซิเดนซ์                               Triple Room Only
# 20  ซันนี เรสซิเดนซ์                               Family Room Only
# 21  ซันนี เรสซิเดนซ์                               Family Room Only
# 22  ซันนี เรสซิเดนซ์                     Triple Room With Breakfast
# 23  ซันนี เรสซิเดนซ์                     Triple Room With Breakfast
# 24  ซันนี เรสซิเดนซ์              Triple Room With One Way Transfer
# 25  ซันนี เรสซิเดนซ์              Triple Room With One Way Transfer
# 26  ซันนี เรสซิเดนซ์                     Family Room With Breakfast
# 27  ซันนี เรสซิเดนซ์                     Family Room With Breakfast
# 28  ซันนี เรสซิเดนซ์              Family Room With One Way Transfer
# 29  ซันนี เรสซิเดนซ์              Family Room With One Way Transfer
# 30  ซันนี เรสซิเดนซ์           Triple Room With Round Trip Transfer
# 31  ซันนี เรสซิเดนซ์           Triple Room With Round Trip Transfer
# 32  ซันนี เรสซิเดนซ์        Triple Room With Breakfast And Transfer
# 33  ซันนี เรสซิเดนซ์        Triple Room With Breakfast And Transfer
# 34  ซันนี เรสซิเดนซ์           Family Room With Round Trip Transfer
# 35  ซันนี เรสซิเดนซ์           Family Room With Round Trip Transfer
# 36  ซันนี เรสซิเดนซ์        Family Room With Breakfast And Transfer
# 37  ซันนี เรสซิเดนซ์        Family Room With Breakfast And Transfer
#
#                           bedType               refund        breakfast  \
# 0                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 1                   เตียงควีนไซส์  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 2                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 3                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 4                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 5                   เตียงควีนไซส์  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 6                            None  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 7                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 8                            None  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 9                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 0                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 1                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 2                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 3                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 4                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 5                   2 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 6                   2 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 7                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 8                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 9                     1 เตียงใหญ่  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 10                    1 เตียงใหญ่  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 11                           None  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 12                           None  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 13                  2 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 14                  2 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 15                           None  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 16                           None  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 17                           None  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 18                           None  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 19                           None  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 20  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 21  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 22                           None  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 23                           None  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 24                           None  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 25                           None  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 26  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 27  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 28  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 29  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 30                           None  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 31                           None  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 32                           None  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 33                           None  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 34  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 35  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้  ไม่รวมอาหารเช้า
# 36  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
# 37  1 เตียงใหญ่ และ 1 เตียงเดี่ยว  ไม่สามารถคืนเงินได้     อาหารเช้าฟรี
#
#                    Wifi    realPrice     disPrice                     Save  \
# 0              WiFi ฟรี  THB1,800.00    THB702.00               Save 61.0%
# 1              WiFi ฟรี  THB2,600.00    THB754.00  71.0% off, Limited time
# 2              WiFi ฟรี  THB2,500.00    THB825.00               Save 67.0%
# 3              WiFi ฟรี  THB2,300.00    THB897.00               Save 61.0%
# 30  ไม่สามารถคืนเงินได้  THB2,000.00  THB1,168.00  41.6% off, Limited time
# 31  ไม่สามารถคืนเงินได้  THB2,000.00  THB1,168.00  41.6% off, Limited time
# 32  ไม่สามารถคืนเงินได้  THB2,200.00  THB1,284.80  41.6% off, Limited time
# 33  ไม่สามารถคืนเงินได้  THB2,200.00  THB1,284.80  41.6% off, Limited time
# 34  ไม่สามารถคืนเงินได้  THB2,300.00  THB1,343.20  41.6% off, Limited time
# 35  ไม่สามารถคืนเงินได้  THB2,300.00  THB1,343.20  41.6% off, Limited time
# 36  ไม่สามารถคืนเงินได้  THB2,880.00  THB1,681.92  41.6% off, Limited time
# 37                 None  THB2,880.00  THB1,681.92  41.6% off, Limited time
#
#                     Tax
# 0   รวมค่าธรรมเนียมแล้ว
# 1   รวมค่าธรรมเนียมแล้ว
# 2   รวมค่าธรรมเนียมแล้ว
# 3   รวมค่าธรรมเนียมแล้ว
# 4   รวมค่าธรรมเนียมแล้ว
# 5   รวมค่าธรรมเนียมแล้ว
# 6   รวมค่าธรรมเนียมแล้ว
# 7   รวมค่าธรรมเนียมแล้ว
# 8   รวมค่าธรรมเนียมแล้ว
# 9   รวมค่าธรรมเนียมแล้ว
# 0   รวมค่าธรรมเนียมแล้ว
# 1   รวมค่าธรรมเนียมแล้ว
# 2   รวมค่าธรรมเนียมแล้ว
# 3   รวมค่าธรรมเนียมแล้ว
# 4   รวมค่าธรรมเนียมแล้ว
# 5   รวมค่าธรรมเนียมแล้ว
# 6   รวมค่าธรรมเนียมแล้ว
# 7   รวมค่าธรรมเนียมแล้ว
# 8   รวมค่าธรรมเนียมแล้ว
# 9   รวมค่าธรรมเนียมแล้ว
# 10  รวมค่าธรรมเนียมแล้ว
# 11  รวมค่าธรรมเนียมแล้ว
# 12  รวมค่าธรรมเนียมแล้ว
# 13  รวมค่าธรรมเนียมแล้ว
# 14  รวมค่าธรรมเนียมแล้ว
# 15  รวมค่าธรรมเนียมแล้ว
# 16  รวมค่าธรรมเนียมแล้ว
# 17  รวมค่าธรรมเนียมแล้ว
# 18  รวมค่าธรรมเนียมแล้ว
# 19  รวมค่าธรรมเนียมแล้ว
# 20  รวมค่าธรรมเนียมแล้ว
# 21  รวมค่าธรรมเนียมแล้ว
# 22  รวมค่าธรรมเนียมแล้ว
# 23  รวมค่าธรรมเนียมแล้ว
# 24  รวมค่าธรรมเนียมแล้ว
# 25  รวมค่าธรรมเนียมแล้ว
# 26  รวมค่าธรรมเนียมแล้ว
# 27  รวมค่าธรรมเนียมแล้ว
# 28  รวมค่าธรรมเนียมแล้ว
# 29  รวมค่าธรรมเนียมแล้ว
# 30  รวมค่าธรรมเนียมแล้ว
# 31  รวมค่าธรรมเนียมแล้ว
# 32  รวมค่าธรรมเนียมแล้ว
# 33  รวมค่าธรรมเนียมแล้ว
# 34  รวมค่าธรรมเนียมแล้ว
# 35  รวมค่าธรรมเนียมแล้ว
# 36  รวมค่าธรรมเนียมแล้ว
# 37  รวมค่าธรรมเนียมแล้ว
