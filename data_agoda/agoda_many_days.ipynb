# %%
# %run agoda_sresults_url.ipynb
# Out:
# Thu Mar 07 2019 Fri Mar 08 2019
# https://www.agoda.com/pages/agoda/default/DestinationSearchResult.aspx?asq=u2qcKLxwzRU5NDuxJ0kOF3T91go8JoYYMxAgy8FkBH1BN0lGAtYH25sdXoy34qb9iWiLzMITi%2F8v1sTO8L5hnD9H%2BTqAKYZCRrGpe2aGwWvI4EUGzOaqndGsXX%2BAlig9ffuorKcIqWxsH6JUEoHVuj0BcPPZZwqDZ4BPHadZduIe5G7SBzk%2BJOTHfval8iN2WaoYtZmgpreaMNKzwOsz4g%3D%3D&city=9395&tick=636872301903&txtuuid=8e87f39b-eac3-4eb0-af4a-9153343fc503&languageId=1&userId=d771f3d7-9006-4ee4-b907-e828da700733&sessionId=0ip4alw3wodtv3ucesxbm3r1&pageTypeId=1&origin=TH&locale=en-US&cid=-1&aid=130243&currencyCode=THB&htmlLanguage=en-us&cultureInfoName=en-US&ckuid=d771f3d7-9006-4ee4-b907-e828da700733&prid=0&checkIn=2019-03-07&checkOut=2019-03-08&rooms=1&adults=2&children=0&priceCur=THB&los=1&textToSearch=Bangkok&productType=-1&travellerType=1

# %%
it = 0

# %%
for url in search_res_url:
    agoda_link = url
    
    # %run Agoda-Web-Scraping-2.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Desktop\coding\HotelPricePrediction\data_agoda\Agoda-Web-Scraping-2.ipynb in <module>()
#      57                                 room_type_element = driver.find_element_by_xpath('//div[@id="' + hotel_id + '"]//span[@data-selenium="masterroom-title-name"]')
#      58                                 last_2page_height = scroll_page_till_find(scroll_pause_time,last_2page_height,scroll_2page_height,room_type_element,driver)
# ---> 59                                 feature_data = [find_hotel_feature(driver,hotel_id,room_type_element)]*len(hotel_user_Ratings)
#      60                             else:
#      61                                 feature_data = [None]*len(hotel_user_Ratings)
#
# ~\Desktop\coding\HotelPricePrediction\data_agoda\Agoda-Web-Scraping-2.ipynb in find_hotel_feature(driver, hotel_id, room_type_element)
# ...
