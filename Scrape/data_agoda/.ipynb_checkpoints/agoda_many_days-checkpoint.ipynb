# %%
# %run agoda_sresults_url.ipynb
# Out:
# Fri Mar 01 2019 Sat Mar 02 2019
# Sat Mar 02 2019 Sun Mar 03 2019
# Sun Mar 03 2019 Mon Mar 04 2019
# https://www.agoda.com/pages/agoda/default/DestinationSearchResult.aspx?asq=u2qcKLxwzRU5NDuxJ0kOF3T91go8JoYYMxAgy8FkBH1BN0lGAtYH25sdXoy34qb9iWiLzMITi%2F8v1sTO8L5hnOR7S%2FdShlb8EZqQ3RwO08is1xlhUdy1hjjV1oP9s06uffuorKcIqWxsH6JUEoHVuj0BcPPZZwqDZ4BPHadZduIe5G7SBzk%2BJOTHfval8iN2WaoYtZmgpreaMNKzwOsz4g%3D%3D&city=9395&tick=636867034188&txtuuid=6cc4d167-6ce9-4fd2-819b-ad32a2c34b24&languageId=1&userId=62ffeb75-909b-4e68-95e6-93407f5697ad&sessionId=xy5xdwpmazanzxvtyuhocudo&pageTypeId=1&origin=TH&locale=en-US&cid=-1&aid=130243&currencyCode=THB&htmlLanguage=en-us&cultureInfoName=en-US&ckuid=62ffeb75-909b-4e68-95e6-93407f5697ad&prid=0&checkIn=2019-03-01&checkOut=2019-03-02&rooms=1&adults=2&children=0&priceCur=THB&los=1&textToSearch=Bangkok&productType=-1&travellerType=1
#
# ...

# %%
for url in search_res_url:
    agoda_link = url
    
    # %run Agoda-Web-Scraping-2.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Desktop/coding/HotelPricePrediction/Scrape/data_agoda/Agoda-Web-Scraping-2.ipynb in <module>
#      14         click_elements = driver.find_elements_by_xpath('//h3[@class="hotel-name"]') # get the original click element
#      15     while True:
# ---> 16         last_height = scroll_page_till_find(scroll_pause_time,last_height,scroll_height,click_elements[element_index],driver)
#      17         time.sleep(2) # wait for the data to be loaded
#      18         click_elements_new = driver.find_elements_by_xpath('//h3[@class="hotel-name"]') # get the loaded data
#
# NameError: name 'last_height' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ...
